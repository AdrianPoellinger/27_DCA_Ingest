# %%
# 📁 Globale Parameter definieren
CSV_PATH_3 = "/home/renku/work/dca-metadataraw/Semiramis/2104_mockup_results/analysis_result_2.csv"

# %%
# !pip install pandas
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 68.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 29.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 64.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 23.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
df1 = pd.read_csv(CSV_PATH_3)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1 = pd.read_csv(CSV_PATH_3)
#
# File ~/work/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df1
# Out:
#       ID  PARENT_ID                                                URI  \
# 0      1        NaN  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 1      2        1.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 2      3        2.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 3      4        3.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 4      5        4.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# ..   ...        ...                                                ...
# 397  398      397.0  zip:file:///home/jovyan/work/dca-digitalmateri...
# 398  399      327.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 399  400      327.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 400  401      327.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
# 401  402      327.0  file:/home/jovyan/work/dca-digitalmaterialcopi...
#
#                                              FILE_PATH                   NAME  \
# ...
